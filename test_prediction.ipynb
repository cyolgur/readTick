# %%
import numpy as np
import pandas as pd
from datetime import datetime, time, date
import os
import sys
sys.path.append('C:/handle_tickdata_order')
from constructRes import read, statistics

# %%
src_path = 'F:\\tickPrediction'
name = 'consectiveSign_{}'
para = [1, 2, 5, 10]

# %%
for i in para:
    print(i)
    tmpPath = os.path.join(src_path, name.format(i))
    fileDict = read(tmpPath)
    statistics(fileDict['numCorrect'], 
           fileDict['numPredict'],
           fileDict['sumLoss'],
           fileDict['sumChange'])
    statistics(fileDict['flagCorrect'], 
       fileDict['flagPredict'],
       fileDict['flagLoss'],
       fileDict['flagChange'])
# Out:
# 1
#            correct     loss
# (2020, 10)  0.0635  -0.9160
# (2020, 11)  0.0546  -0.9245
# (2020, 12)  0.0649  -0.9020
# (2021, 1)   0.0667  -0.9032
# (2021, 2)   0.0739  -0.8888
# (2021, 3)   0.0829  -0.8705
# (2021, 4)   0.0646  -0.9001
# (2021, 5)   0.0874  -0.8570
# (2021, 6)   0.0733  -0.8857
# (2021, 7)   0.0688  -0.8830
# (2021, 8)   0.0664  -0.8859
# (2021, 9)   0.0791  -0.8704
# total       0.0714  -0.8875
#            correct     loss
# (2020, 10)  0.0588  -0.9077
# (2020, 11)  0.0545  -0.9140
# (2020, 12)  0.0708  -0.8833
# (2021, 1)   0.0679  -0.8920
# (2021, 2)   0.0762  -0.8728
# (2021, 3)   0.0885  -0.8513
# (2021, 4)   0.0675  -0.8834
# (2021, 5)   0.1031  -0.8246
# (2021, 6)   0.0787  -0.8698
# (2021, 7)   0.0773  -0.8633
# (2021, 8)   0.0813  -0.8572
# (2021, 9)   0.0945  -0.8371
# total       0.0786  -0.8672
# 2
#            correct     loss
# (2020, 10)  0.0633  -0.9048
# (2020, 11)  0.0560  -0.9139
# (2020, 12)  0.0680  -0.8864
# (2021, 1)   0.0691  -0.8890
# ...

# %%
src_path = 'F:\\tickPrediction'
name = 'volImbalance_sum_{}'
para = [1, 2, 5, 10]

for i in para:
    print(i)
    tmpPath = os.path.join(src_path, name.format(i))
    fileDict = read(tmpPath)
    statistics(fileDict['numCorrect'], 
           fileDict['numPredict'],
           fileDict['sumLoss'],
           fileDict['sumChange'])
    statistics(fileDict['flagCorrect'], 
       fileDict['flagPredict'],
       fileDict['flagLoss'],
       fileDict['flagChange'])
# Out:
# 1
#            correct     loss
# (2020, 10)  0.1485  -0.5027
# (2020, 11)  0.1434  -0.4993
# (2020, 12)  0.1543  -0.5037
# (2021, 1)   0.1612  -0.5019
# (2021, 2)   0.1621  -0.5029
# (2021, 3)   0.1681  -0.5043
# (2021, 4)   0.1575  -0.4993
# (2021, 5)   0.1729  -0.5090
# (2021, 6)   0.1627  -0.5031
# (2021, 7)   0.1514  -0.5004
# (2021, 8)   0.1505  -0.5017
# (2021, 9)   0.1623  -0.5068
# total       0.1583  -0.5030
#            correct     loss
# (2020, 10)  0.1702  -0.5114
# (2020, 11)  0.1690  -0.5072
# (2020, 12)  0.1812  -0.5113
# (2021, 1)   0.1871  -0.5084
# (2021, 2)   0.1895  -0.5111
# (2021, 3)   0.1945  -0.5139
# (2021, 4)   0.1829  -0.5077
# (2021, 5)   0.2019  -0.5199
# (2021, 6)   0.1897  -0.5106
# (2021, 7)   0.1781  -0.5086
# (2021, 8)   0.1808  -0.5129
# (2021, 9)   0.1900  -0.5173
# total       0.1853  -0.5118
# 2
#            correct     loss
# (2020, 10)  0.1495  -0.5023
# (2020, 11)  0.1441  -0.4997
# (2020, 12)  0.1556  -0.5016
# (2021, 1)   0.1625  -0.5002
# ...

# %%
src_path = 'F:\\tickPrediction'
name = 'volImbalance_signsum_{}'
para = [1, 2, 5, 10]

for i in para:
    print(i)
    tmpPath = os.path.join(src_path, name.format(i))
    fileDict = read(tmpPath)
    statistics(fileDict['numCorrect'], 
           fileDict['numPredict'],
           fileDict['sumLoss'],
           fileDict['sumChange'])
    statistics(fileDict['flagCorrect'], 
       fileDict['flagPredict'],
       fileDict['flagLoss'],
       fileDict['flagChange'])
# Out:
# 1
#            correct     loss
# (2020, 10)  0.1485  -0.5027
# (2020, 11)  0.1434  -0.4993
# (2020, 12)  0.1543  -0.5037
# (2021, 1)   0.1612  -0.5019
# (2021, 2)   0.1621  -0.5029
# (2021, 3)   0.1681  -0.5043
# (2021, 4)   0.1575  -0.4993
# (2021, 5)   0.1729  -0.5090
# (2021, 6)   0.1627  -0.5031
# (2021, 7)   0.1514  -0.5004
# (2021, 8)   0.1505  -0.5017
# (2021, 9)   0.1623  -0.5068
# total       0.1583  -0.5030
#            correct     loss
# (2020, 10)  0.1702  -0.5114
# (2020, 11)  0.1690  -0.5072
# (2020, 12)  0.1812  -0.5113
# (2021, 1)   0.1871  -0.5084
# (2021, 2)   0.1895  -0.5111
# (2021, 3)   0.1945  -0.5139
# (2021, 4)   0.1829  -0.5077
# (2021, 5)   0.2019  -0.5199
# (2021, 6)   0.1897  -0.5106
# (2021, 7)   0.1781  -0.5086
# (2021, 8)   0.1808  -0.5129
# (2021, 9)   0.1900  -0.5173
# total       0.1853  -0.5118
# 2
#            correct     loss
# (2020, 10)  0.1454  -0.5016
# (2020, 11)  0.1405  -0.4990
# (2020, 12)  0.1512  -0.5008
# (2021, 1)   0.1586  -0.4996
# ...

# %%
src_path = 'F:\\tickPrediction'
name = 'volImbalanceIncre_signsum_{}'
para = [1, 2, 5, 10]

for i in para:
    print(i)
    tmpPath = os.path.join(src_path, name.format(i))
    fileDict = read(tmpPath)
    statistics(fileDict['numCorrect'], 
           fileDict['numPredict'],
           fileDict['sumLoss'],
           fileDict['sumChange'])
    statistics(fileDict['flagCorrect'], 
       fileDict['flagPredict'],
       fileDict['flagLoss'],
       fileDict['flagChange'])
# Out:
# 1
#            correct     loss
# (2020, 10)  0.1705  -0.4318
# (2020, 11)  0.1658  -0.4245
# (2020, 12)  0.1757  -0.4389
# (2021, 1)   0.1827  -0.4379
# (2021, 2)   0.1830  -0.4421
# (2021, 3)   0.1848  -0.4603
# (2021, 4)   0.1772  -0.4391
# (2021, 5)   0.1907  -0.4656
# (2021, 6)   0.1833  -0.4463
# (2021, 7)   0.1708  -0.4421
# (2021, 8)   0.1713  -0.4414
# (2021, 9)   0.1844  -0.4495
# total       0.1786  -0.4445
#            correct     loss
# (2020, 10)  0.1897  -0.4533
# (2020, 11)  0.1895  -0.4440
# (2020, 12)  0.1987  -0.4608
# (2021, 1)   0.2042  -0.4595
# (2021, 2)   0.2064  -0.4649
# (2021, 3)   0.2065  -0.4824
# (2021, 4)   0.2003  -0.4575
# (2021, 5)   0.2146  -0.4894
# (2021, 6)   0.2070  -0.4643
# (2021, 7)   0.1951  -0.4616
# (2021, 8)   0.1982  -0.4660
# (2021, 9)   0.2071  -0.4742
# total       0.2020  -0.4660
# 2
#            correct     loss
# (2020, 10)  0.1603  -0.4329
# (2020, 11)  0.1560  -0.4236
# (2020, 12)  0.1647  -0.4410
# (2021, 1)   0.1724  -0.4394
# ...

# %%
src_path = 'F:\\tickPrediction'
name = 'amountImbalanceIncre_signsum_{}'
para = [1, 2, 5, 10]

for i in para:
    print(i)
    tmpPath = os.path.join(src_path, name.format(i))
    fileDict = read(tmpPath)
    statistics(fileDict['numCorrect'], 
           fileDict['numPredict'],
           fileDict['sumLoss'],
           fileDict['sumChange'])
    statistics(fileDict['flagCorrect'], 
       fileDict['flagPredict'],
       fileDict['flagLoss'],
       fileDict['flagChange'])
# Out:
# 1
#            correct     loss
# (2020, 10)  0.1708  -0.4338
# (2020, 11)  0.1658  -0.4268
# (2020, 12)  0.1758  -0.4409
# (2021, 1)   0.1828  -0.4400
# (2021, 2)   0.1835  -0.4441
# (2021, 3)   0.1854  -0.4617
# (2021, 4)   0.1772  -0.4412
# (2021, 5)   0.1911  -0.4668
# (2021, 6)   0.1833  -0.4482
# (2021, 7)   0.1707  -0.4441
# (2021, 8)   0.1711  -0.4434
# (2021, 9)   0.1848  -0.4513
# total       0.1788  -0.4464
#            correct     loss
# (2020, 10)  0.1895  -0.4545
# (2020, 11)  0.1891  -0.4454
# (2020, 12)  0.1983  -0.4618
# (2021, 1)   0.2038  -0.4606
# (2021, 2)   0.2063  -0.4658
# (2021, 3)   0.2062  -0.4830
# (2021, 4)   0.1999  -0.4588
# (2021, 5)   0.2144  -0.4897
# (2021, 6)   0.2065  -0.4654
# (2021, 7)   0.1946  -0.4627
# (2021, 8)   0.1979  -0.4670
# (2021, 9)   0.2071  -0.4749
# total       0.2017  -0.4669
# 2
#            correct     loss
# (2020, 10)  0.1591  -0.4323
# (2020, 11)  0.1549  -0.4228
# (2020, 12)  0.1636  -0.4406
# (2021, 1)   0.1713  -0.4388
# ...

# %%
src_path = 'F:\\tickPrediction'
name = 'orderImbalance1_signsum_{}'
para = [1, 2, 5, 10, 15]

for i in para:
    tmpPath = os.path.join(src_path, name.format(i))
    fileDict = read(tmpPath)
    statistics(fileDict['correctNum'], 
           fileDict['totalNum'],
           fileDict['lossChange'],
           fileDict['totalChange'])
# Out:
#            correct     loss
# (2020, 10)  0.1441  -0.5555
# (2020, 11)  0.1364  -0.5637
# (2020, 12)  0.1511  -0.5506
# (2021, 1)   0.1567  -0.5517
# (2021, 2)   0.1603  -0.5449
# (2021, 3)   0.1719  -0.5261
# (2021, 4)   0.1542  -0.5459
# (2021, 5)   0.1796  -0.5209
# (2021, 6)   0.1624  -0.5408
# (2021, 7)   0.1490  -0.5414
# (2021, 8)   0.1487  -0.5440
# (2021, 9)   0.1657  -0.5346
# total       0.1574  -0.5421
#            correct     loss
# (2020, 10)  0.1429  -0.5438
# (2020, 11)  0.1349  -0.5540
# (2020, 12)  0.1508  -0.5349
# (2021, 1)   0.1565  -0.5366
# (2021, 2)   0.1606  -0.5290
# (2021, 3)   0.1720  -0.5085
# (2021, 4)   0.1528  -0.5325
# (2021, 5)   0.1783  -0.5025
# (2021, 6)   0.1606  -0.5265
# (2021, 7)   0.1477  -0.5293
# (2021, 8)   0.1469  -0.5304
# (2021, 9)   0.1643  -0.5177
# total       0.1564  -0.5273
#            correct     loss
# (2020, 10)  0.1534  -0.5098
# (2020, 11)  0.1456  -0.5160
# (2020, 12)  0.1611  -0.5019
# (2021, 1)   0.1674  -0.5034
# ...

# %%
pd.DataFrame(a).T
# Out:
#        1    2    3    5
# 123  2.0  3.0  4.0  NaN
# 234  2.0  NaN  4.0  5.0

# %%
a = np.array([[1,2,3],[2,3,4]])
b = np.array([1,2])
b = np.expand_dims(b, axis=1)

# %%
q = pd.DataFrame(np.concatenate([a,b], axis=1))

# %%
q.shape
# Out:
# (2, 4)

# %%
for i in range(q.shape[0]):
    print(q.iloc[i,:].to_dict())
# Out:
# {0: 1, 1: 2, 2: 3, 3: 1}
# {0: 2, 1: 3, 2: 4, 3: 2}

# %%
a
# Out:
# [1, 2, 3, 4]

# %%
np.maximum([np.nan,-1,1], 0)
# Out:
# array([nan,  0.,  1.])

# %%
pd.read_csv()
